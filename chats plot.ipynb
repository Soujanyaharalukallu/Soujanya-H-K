# %% [markdown]
# # Line chat

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\Soujanya\OneDrive\Documents\User_Data.csv")
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df['Age'].plot()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %% [markdown]
# # Scatter chart

# %%
df.plot(kind = 'scatter', x = 'Age', y = 'EstimatedSalary')
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
df["Age"].corr(df['EstimatedSalary'])
# Out:
# 0.15523801797209996

# %% [markdown]
# # Histogram

# %%
df["Age"].plot(kind = 'hist',bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["EstimatedSalary"].plot(kind = 'hist',bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['Age','EstimatedSalary']].plot(kind = 'hist',bins = 5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1 = pd.read_csv(r"C:\Users\Soujanya\OneDrive\Documents\Salaries.csv")
df1[["phd",'service']].plot(kind = 'hist',bins = 10,alpha = 0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    204
# Male      196
# Name: count, dtype: int64

# %%
df['Age'].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
Rank_totals = round(df.groupby("Gender")["EstimatedSalary"].mean(),2)
print(Rank_totals)
Rank_totals.plot(kind = 'bar',alpha = 0.6)
# Out:
# Gender
# Female    71759.80
# Male      67642.86
# Name: EstimatedSalary, dtype: float64
# <Axes: xlabel='Gender'>

# %%
Rank_totals = df1.groupby(["rank"])[["service","phd"]].mean()
print(Rank_totals)
Rank_totals.plot(kind = 'bar',alpha = 0.6,stacked = True)
# Out:
#              service        phd
# rank
# AssocProf  11.307692  15.076923
# AsstProf    2.210526   5.052632
# Prof       21.413043  27.065217
# <Axes: xlabel='rank'>

# %%
Rank_totals.plot(kind = 'barh',alpha = 0.6,stacked = True)
# Out:
# <Axes: ylabel='rank'>

# %% [markdown]
# # Pie chart

# %%
Rank_totals.plot(kind = 'pie',subplots = True)
# Out:
# array([<Axes: ylabel='service'>, <Axes: ylabel='phd'>], dtype=object)

# %%
df['Age'].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
Rank_totals.plot.bar(color =['green','red'],subplots = True,rot = 45)
# Out:
# array([<Axes: title={'center': 'service'}, xlabel='rank'>,
#        <Axes: title={'center': 'phd'}, xlabel='rank'>], dtype=object)

# %% [markdown]
# # Box plot

# %%
df['EstimatedSalary'].plot(kind = 'box',)
# Out:
# <Axes: >

# %%
df[["Age","EstimatedSalary"]].plot.box()
# Out:
# <Axes: >

# %%
df["Purchased"].plot.box()
# Out:
# <Axes: >

# %%
import numpy as np

q1 = np.quantile(df1['salary'],0.5)
print('q1',q1)

q2 = np.quantile(df1['salary'],0.25)
print('q2',q2)

q3 = np.quantile(df1['salary'],0.75)
print('q3',q3)

iqr = (q3-q1)
print('iqr',iqr)

[q3-1.5*iqr, q1+1.5*iqr]

min,max = q3-1.5*iqr,q1+1.5*iqr
iqrange = [min,max]
iqrange
# Out:
# q1 nan
# q2 nan
# q3 nan
# iqr nan
# [nan, nan]

# %%
salary_in_range = df1[(df1['salary'] >=min
salary_in_range = df1[(df1['salary'] >=min) & (df1['salary']<=max)]
salary_in_range.count()
# Out:
#   Cell In[22], line 1
#     salary_in_range = df1[(df1['salary'] >=min
#                           ^
# SyntaxError: '(' was never closed

# %%
salary_in_range = df1[(df1['salary'])]
df[['service', 'phd']].plot(kind = 'box')

# %% [markdown]
# # Area plot

# %%
df1[['service','phd']].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df1[['service','phd']].plot(kind = 'area',alpha = 0.3)
# Out:
# <Axes: >

# %% [markdown]
# # Hexabin plot

# %%
df.plot(kind = 'scatter',x = 'service',y = 'salary',figsize=(8,4),
       title = 'salary and service infromation', ylable = 'salary in Rupees',
       xlable ='Experince as service',marker = 'x',color = 'magenta');

# %%
df.plot(kind = 'hexbin',x = 'service',y = 'salary',gridsize=10,figsize=(8,4))

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df,alpha=1, figsize=(10,6))
# Out:
# array([[<Axes: xlabel='User ID', ylabel='User ID'>,
#         <Axes: xlabel='Age', ylabel='User ID'>,
#         <Axes: xlabel='EstimatedSalary', ylabel='User ID'>,
#         <Axes: xlabel='Purchased', ylabel='User ID'>],
#        [<Axes: xlabel='User ID', ylabel='Age'>,
#         <Axes: xlabel='Age', ylabel='Age'>,
#         <Axes: xlabel='EstimatedSalary', ylabel='Age'>,
#         <Axes: xlabel='Purchased', ylabel='Age'>],
#        [<Axes: xlabel='User ID', ylabel='EstimatedSalary'>,
#         <Axes: xlabel='Age', ylabel='EstimatedSalary'>,
#         <Axes: xlabel='EstimatedSalary', ylabel='EstimatedSalary'>,
#         <Axes: xlabel='Purchased', ylabel='EstimatedSalary'>],
#        [<Axes: xlabel='User ID', ylabel='Purchased'>,
#         <Axes: xlabel='Age', ylabel='Purchased'>,
#         <Axes: xlabel='EstimatedSalary', ylabel='Purchased'>,
#         <Axes: xlabel='Purchased', ylabel='Purchased'>]], dtype=object)

# %%
from pandas.plotting import bootstrap_plot
bootstrap_plot(df['EstimatedSalary'])
